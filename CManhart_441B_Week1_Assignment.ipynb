# %% [markdown]
# ## **ECON 441B - WEEK 1 Assignment**
# Courtney Manhart

# %%
# Import Necessary Packages & Google Drive
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# Import Data
data = pd.read_csv('/content/gdrive/MyDrive/ECON441B/winequality-red.csv')
data
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# Make Visualization
plt.figure(figsize = (10, 6))

plt.hist(data['fixed_acidity'], bins = 'fd')
plt.title("Histogram of Fixed Acidity")
plt.xlabel('Fixed Acidity')
plt.ylabel('Count')
plt.grid()
plt.show()

# %% [markdown]
# This figure shows the histogram of Fixed Acidity from the dataset. We can see that the data is skewed with outliers in the upper tail.
